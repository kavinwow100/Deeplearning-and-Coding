# %% [markdown]
# ## 双向RNN模型
# 例子：
# * 我___
# * 我___难过。
# * 我___难过。哭了一下午。
#
# ![image-2.png](attachment:image-2.png)
# ![image-4.png](attachment:image-4.png)
#
# ![image-3.png](attachment:image-3.png)

# %%
import torch
from torch import nn
import dltools

# 加载数据
batch_size, num_steps, device = 32, 35, dltools.try_gpu()
train_iter, vocab = dltools.load_data_time_machine(batch_size, num_steps)

# %%
# 通过设置“bidirective=True”来定义双向LSTM模型
vocab_size, num_hiddens, num_layers = len(vocab), 256, 2
num_inputs = vocab_size
lstm_layer = nn.LSTM(num_inputs, num_hiddens, num_layers, bidirectional=True)
model = dltools.RNNModel(lstm_layer, len(vocab))
model = model.to(device)

# %%
# 训练模型
num_epochs, lr = 50, 1
dltools.train_ch8(model, train_iter, vocab, lr, num_epochs, device)
# Out:
# perplexity 4.1, 1635.0 tokens/sec on cpu
# time travellereeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# travellereeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
