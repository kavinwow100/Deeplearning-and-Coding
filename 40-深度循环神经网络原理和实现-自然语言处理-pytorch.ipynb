# %% [markdown]
# ## 深度循环神经网络
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
import torch
from torch import nn
import dltools
batch_size, num_steps = 32, 35
train_iter, vocab = dltools.load_data_time_machine(batch_size, num_steps)

# %%
vocab_size, num_hiddens, num_layers = len(vocab), 256, 2
num_inputs = vocab_size
device = dltools.try_gpu()
lstm_layer = nn.LSTM(num_inputs, num_hiddens, num_layers)
model = dltools.RNNModel(lstm_layer, len(vocab))
model = model.to(device)

# %%
# 训练与预测
num_epochs, lr = 50, 2
dltools.train_ch8(model, train_iter, vocab, lr, num_epochs, device)
# Out:
# perplexity 14.0, 3120.9 tokens/sec on cpu
# time travellere the tan the tan the tan the tan the tan the tan
# travellere the tan the tan the tan the tan the tan the tan
