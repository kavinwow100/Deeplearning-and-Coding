# %% [markdown]
# 1. 分布偏移的类型
#     * 协变量偏移：虽然输入的分布可能随时间而改变，但标签函数没有改变。
#     ![image.png](attachment:image.png)
#     ![image-2.png](attachment:image-2.png)
#     * 标签偏移：标签偏移描述了与协变量偏移相反的问题。
#     * 概念偏移
# 2. 分布偏移示例
#     * 医学诊断
#     * 自动驾驶汽车
#     * 非平稳分布：当分布变化缓慢并且模型没有得到充分更新时，就会出现更微妙的情况
